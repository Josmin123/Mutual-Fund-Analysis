# %%
# !pip install quantstats
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: quantstats in c:\users\ananya p\appdata\roaming\python\python310\site-packages (0.0.64)
# Requirement already satisfied: pandas>=0.24.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (2.1.3)
# Requirement already satisfied: seaborn>=0.9.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (3.5.2)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (1.14.1)
# Requirement already satisfied: tabulate>=0.8.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (0.2.50)
# Requirement already satisfied: python-dateutil>=2.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from quantstats) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from matplotlib>=3.0.0->quantstats) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from pandas>=0.24.0->quantstats) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from pandas>=0.24.0->quantstats) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.0->quantstats) (1.16.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.4.1)
# Requirement already satisfied: webencodings in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ananya p\appdata\roaming\python\python310\site-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2023.7.22)

# %% [markdown]
# **Market Value Calculation**
#
# -We will calculate the market_value

# %%
def cal_market_value(pos_df):
    """Calculate market value by multiplying quantity, mtm_price, and base_factor."""
    pos_df['market_value'] = pos_df['quantity'] * pos_df['mtm_price'] * pos_df['base_factor']
    return pos_df

# %% [markdown]
# **Getting the data for processing**
#
# *   Read the file
# *   Process the data if the columns exist

# %%
def get_data(filepath):
    """Load the data and check for required columns."""
    try:
        pos_df = pd.read_csv(filepath)
        logging.info("File loaded successfully.")

        required_columns = ['quantity', 'mtm_price', 'base_factor', 'report_date']

        # Verify required columns
        if all(col in pos_df.columns for col in required_columns):
            pos_df = cal_market_value(pos_df)
            return pos_df
        else:
            missing_cols = [col for col in required_columns if col not in pos_df.columns]
            logging.error(f"Missing columns: {missing_cols}")
            return None
    except FileNotFoundError:
        logging.error(f"File not found: {filepath}")
    except Exception as e:
        logging.error(f"An error occurred: {e}")

# %% [markdown]
# **Merging Position and Security Sheet**
# *   Get postion data and security data
# *   And merge pos_data and security_df using 'security_id' from pos_data and 'symbol' from security_df

# %%
def merge_pos_security_sheet(filepath1, filepath2):
    # Load and prepare position data
    pos_data = get_data(filepath1)
    # pos_data=pd.read_csv(filepath1)
    # Load security sheet data
    security_df = pd.read_csv(filepath2)


    # Merge dataframes on 'security_id' from pos_data and 'symbol' from security_df
    merged_df = pd.merge(pos_data, security_df, left_on='security_id', right_on='symbol', how='inner')
    #print(merged_df['client_id'].unique())

    # Print merged dataframe for verification
    return merged_df

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import logging
import time
import warnings
import quantstats as qs  # For enhanced financial statistics

warnings.filterwarnings("ignore")

# Initialize logging once
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Program Files\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Program Files\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Program Files\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "c:\Program Files\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "c:\Program Files\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Temp\ipykernel_11784\1897305298.py", line 8, in <module>
#     import quantstats as qs  # For enhanced financial statistics
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\quantstats\__init__.py", line 26, in <module>
#     from . import stats, utils, plots, reports
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\quantstats\plots.py", line 24, in <module>
#     _rmc()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_misc.py", line 108, in register
#     plot_backend = _get_plot_backend("matplotlib")
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py", line 1944, in _get_plot_backend
#     module = _load_backend(backend_str)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_core.py", line 1872, in _load_backend
#     module = importlib.import_module("pandas.plotting._matplotlib")
#   File "c:\Program Files\Python310\lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\__init__.py", line 5, in <module>
#     from pandas.plotting._matplotlib.boxplot import (
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\pandas\plotting\_matplotlib\boxplot.py", line 10, in <module>
#     from matplotlib.artist import setp
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py", line 109, in <module>
#     from . import _api, _version, cbook, docstring, rcsetup
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, cbook, scale
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\scale.py", line 23, in <module>
#     from matplotlib.ticker import (
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\ticker.py", line 136, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\transforms.py", line 46, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Program Files\Python310\lib\runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "c:\Program Files\Python310\lib\runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelapp.py", line 728, in start
#     self.io_loop.start()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "c:\Program Files\Python310\lib\asyncio\base_events.py", line 600, in run_forever
#     self._run_once()
#   File "c:\Program Files\Python310\lib\asyncio\base_events.py", line 1896, in _run_once
#     handle._run()
#   File "c:\Program Files\Python310\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\ipykernel\zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Temp\ipykernel_11784\1897305298.py", line 8, in <module>
#     import quantstats as qs  # For enhanced financial statistics
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\quantstats\__init__.py", line 26, in <module>
#     from . import stats, utils, plots, reports
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\quantstats\plots.py", line 28, in <module>
#     from quantstats._plotting.wrappers import *
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\quantstats\_plotting\wrappers.py", line 22, in <module>
#     import matplotlib.pyplot as _plt
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py", line 109, in <module>
#     from . import _api, _version, cbook, docstring, rcsetup
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, cbook, scale
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\scale.py", line 23, in <module>
#     from matplotlib.ticker import (
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\ticker.py", line 136, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\Ananya P\AppData\Roaming\Python\Python310\site-packages\matplotlib\transforms.py", line 46, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 import time
#       7 import warnings
# ----> 8 import quantstats as qs  # For enhanced financial statistics
#      10 warnings.filterwarnings("ignore")
#      12 # Initialize logging once
#
# File ~\AppData\Roaming\Python\Python310\site-packages\quantstats\__init__.py:26
#      23 __version__ = version.version
#      24 __author__ = "Ran Aroussi"
# ---> 26 from . import stats, utils, plots, reports
#      28 __all__ = ["stats", "plots", "reports", "utils", "extend_pandas"]
#      30 # try automatic matplotlib inline
#
# File ~\AppData\Roaming\Python\Python310\site-packages\quantstats\plots.py:28
#      25 except ImportError:
#      26     pass
# ---> 28 from quantstats._plotting.wrappers import *
#
# File ~\AppData\Roaming\Python\Python310\site-packages\quantstats\_plotting\wrappers.py:22
#       1 #!/usr/bin/env python
#       2 # -*- coding: UTF-8 -*-
#       3 #
#    (...)
#      18 # See the License for the specific language governing permissions and
#      19 # limitations under the License.
#      21 import warnings
# ---> 22 import matplotlib.pyplot as _plt
#      23 from matplotlib.ticker import (
#      24     StrMethodFormatter as _StrMethodFormatter,
#      25     FuncFormatter as _FuncFormatter,
#      26 )
#      28 import numpy as _np
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py:109
#     105 from packaging.version import parse as parse_version
#     107 # cbook must import matplotlib only within function
#     108 # definitions, so it is safe to import from it here.
# --> 109 from . import _api, _version, cbook, docstring, rcsetup
#     110 from matplotlib.cbook import MatplotlibDeprecationWarning, sanitize_sequence
#     111 from matplotlib.cbook import mplDeprecation  # deprecated
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib.fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\scale.py:23
#      21 import matplotlib as mpl
#      22 from matplotlib import _api, docstring
# ---> 23 from matplotlib.ticker import (
#      24     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      25     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      26     SymmetricalLogLocator, LogitLocator)
#      27 from matplotlib.transforms import Transform, IdentityTransform
#      30 class ScaleBase:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\ticker.py:136
#     134 import matplotlib as mpl
#     135 from matplotlib import _api, cbook
# --> 136 from matplotlib import transforms as mtransforms
#     138 _log = logging.getLogger(__name__)
#     140 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     141            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     142            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     148            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     149            'SymmetricalLogLocator', 'LogitLocator')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\transforms.py:46
#      43 from numpy.linalg import inv
#      45 from matplotlib import _api
# ---> 46 from matplotlib._path import (
#      47     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      48 from .path import Path
#      50 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# **Returns Calculation**
# *   Filters out rows where filter_column
# *   Find sum of market_value for the selected filter_column
# *   Calculate the daily returs

# %%
def cal_returns(df, filter_column):
    start_time = time.time()
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logging.info("Starting to process data.")

    try:
        # Convert 'report_date' to datetime format to ensure datetime-like accessors work
        df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')

        # Filter the data based on the selected filter_column (e.g., 'asset_class_x')
        df = df[(df['asset_class_x'] != 'Loan') & (df['asset_class_y'] != 'Loan')]
        daily_returns = df.groupby(['report_date', filter_column])['market_value'].sum().reset_index()

        # Rename the 'market_value' column to 'total_market_value'
        daily_returns.rename(columns={'market_value': 'total_market_value'}, inplace=True)

        # Calculate daily returns as the percentage change in 'total_market_value'
        daily_returns['daily_returns'] = daily_returns.groupby(filter_column)['total_market_value'].pct_change()

        logging.info("Calculated daily returns.")

        # Format 'report_date' for JSON output only
        daily_returns_json = daily_returns.copy()
        daily_returns_json['report_date'] = daily_returns_json['report_date'].dt.strftime('%Y-%m-%d')

        # Convert to JSON format for output
        json_output = daily_returns_json[['report_date', filter_column, 'total_market_value', 'daily_returns']].to_json(orient='records', double_precision=2)
        logging.info("Converted data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        # Return original daily_returns for downstream functions and formatted JSON output
        return json_output, total_time, daily_returns

    except Exception as e:
        logging.error("Error processing data: %s", e)
        raise
filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

returns_json, returns_time, daily_returns = cal_returns(merged_data, filter_column)
print("Execution Time:", returns_time, "seconds")
print("Daily Returns:", returns_json)
top_62_rows=daily_returns.head(62)
print("\n")
# top_62_rows.to_csv('top_62_data.csv', index=False)
# print("Top 62 rows saved to 'top_62_data.csv'.")

# daily_returns.head()
daily_returns.tail()

# %% [markdown]
# Monthly Returns

# %%
import pandas as pd
import time
import logging

def cal_monthly_returns(df, filter_column):
    start_time = time.time()
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logging.info("Starting monthly returns calculation.")

    try:
        # Ensure 'report_date' is in datetime format
        df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')

        # Drop rows with invalid dates or missing values
        df.dropna(subset=['report_date', 'quantity', 'mtm_price', 'base_factor'], inplace=True)

        # Filter out unwanted asset classes
        df = df[(df['asset_class_x'] != 'Loan') & (df['asset_class_y'] != 'Loan')]

        # Calculate market value
        df['market_value'] = df['quantity'] * df['mtm_price'] * df.get('base_factor', 1)
        logging.info("Calculated market value.")

        # Group by report_date and filter_column, then sum the market values
        grouped_data = (
            df.groupby(['report_date', filter_column])['market_value']
            .sum()
            .reset_index()
        )
        grouped_data.rename(columns={'market_value': 'total_market_value'}, inplace=True)

        # Resample data to monthly frequency for each group
        grouped_data['report_date'] = pd.to_datetime(grouped_data['report_date'])
        grouped_data.set_index('report_date', inplace=True)

        monthly_performance = grouped_data.groupby(filter_column).resample('M').agg({
            'total_market_value': ['first', 'last']
        })

        # Flatten MultiIndex columns
        monthly_performance.columns = ['start_value', 'end_value']

        # Calculate monthly returns
        monthly_performance['monthly_returns'] = (
            (monthly_performance['end_value'] - monthly_performance['start_value']) / monthly_performance['start_value'] * 100
        )

        # Reset index for final output
        monthly_performance.reset_index(inplace=True)
        monthly_performance.dropna(subset=['monthly_returns'], inplace=True)

        # Add formatted month column
        monthly_performance['month'] = monthly_performance['report_date'].dt.strftime('%b')

        # Prepare final output
        results = monthly_performance[[
            filter_column, 'month', 'start_value', 'end_value', 'monthly_returns'
        ]].rename(columns={
            'monthly_returns': 'return_value'
        })

        # Convert to JSON format
        json_output = results.to_json(orient='records', double_precision=2)
        logging.info("Converted monthly returns data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        # Return JSON output and execution time
        return json_output, total_time,results

    except Exception as e:
        logging.error("Error processing monthly returns: %s", e)
        raise

filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

returns_json, returns_time, results = cal_monthly_returns(merged_data, filter_column)
print("Execution Time:", returns_time, "seconds")
print("Monthly Returns:", returns_json)
print("\n")

# %% [markdown]
# **Risk Calculation**
# *   Filters out rows where filter_column
# *   Find sum of market_value for the selected filter_column
# *   call cal_returns() give sthe daily returns
# *   Calculate risk by groupby filter column for the daily returns

# %%
def cal_risk(df, filter_column):
    start_time = time.time()
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logging.info("Starting risk calculation process.")

    try:
        # Ensure 'report_date' is in datetime format
        df['report_date'] = pd.to_datetime(df['report_date'])

        json_output, total_time,daily_returns=cal_returns(df,filter_column)

        logging.info("Calculated daily returns for risk measurement.")

        # Drop NaN values that may arise from pct_change
        daily_returns.dropna(subset=['daily_returns'], inplace=True)

        # Calculate standard deviation of daily returns for each group (risk measure)
        risk_values = daily_returns.groupby(filter_column)['daily_returns'].std().reset_index()
        risk_values.rename(columns={'daily_returns': 'risk'}, inplace=True)

        # Format 'report_date' to match the desired format (e.g., "YYYY-MM-DD")
        daily_returns['report_date'] = daily_returns['report_date'].dt.strftime('%Y-%m-%d')

        # Merge risk values back to daily_returns to have the 'risk' column
        daily_returns = daily_returns.merge(risk_values, on=filter_column, how='left')

        # Convert to JSON format for output
        json_output = daily_returns[['report_date', filter_column, 'total_market_value', 'risk']].to_json(orient='records', double_precision=2)
        logging.info("Converted risk data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        return json_output, total_time,daily_returns

    except Exception as e:
        logging.error("Error processing risk data: %s", e)
        raise

filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

risk_json, risk_time, daily_returns = cal_risk(merged_data, filter_column)
print("Execution Time:", risk_time, "seconds")
print("Risk:", risk_json)
print("\n")

# %% [markdown]
# **Sharpe Ratio**
# *   Filters out rows where filter_column
# *   Find sum of market_value for the selected filter_column
# *   call cal_returns() give sthe daily returns
# *   Calculate risk by groupby filter column for the daily returns for a month
# *   Calculate the sharpe ratio for each month over the specified period

# %%
def cal_sharpe_ratio(df, filter_column, risk_free_rate=0.03):
    start_time = time.time()
    logging.info("Starting monthly Sharpe Ratio calculation.")

    try:
        # Ensure 'report_date' is in datetime format and set it as index for resampling
        df['report_date'] = pd.to_datetime(df['report_date'])

        json_output, total_time, daily_returns = cal_returns(df, filter_column)

        # Ensure 'daily_returns' has no NaN values
        daily_returns.dropna(subset=['daily_returns'], inplace=True)

        # Set 'report_date' as the index
        daily_returns.set_index('report_date', inplace=True)

        # Resample by month for each group in filter_column and calculate mean and std dev
        monthly_stats = daily_returns.groupby(filter_column).resample('M')['daily_returns'].agg(['mean', 'std']).reset_index()
        monthly_stats.rename(columns={'mean': 'average_daily_return', 'std': 'risk'}, inplace=True)

        # Format 'report_date' to match the desired format (e.g., "YYYY-MM-DD")
        monthly_stats['report_date'] = monthly_stats['report_date'].dt.strftime('%Y-%m-%d')

        # Calculate the Sharpe ratio for each group by month
        monthly_stats['sharpe_ratio'] = (monthly_stats['average_daily_return'] - risk_free_rate) / monthly_stats['risk']

        # Convert to JSON format for output
        json_output = monthly_stats[['report_date', filter_column, 'sharpe_ratio']].to_json(orient='records', double_precision=2)
        logging.info("Converted monthly Sharpe Ratio data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        # Display results
        #print("Sharpe Ratio Results:")
        #print(monthly_stats)


        return json_output, total_time, monthly_stats

    except Exception as e:
        logging.error("Error calculating monthly Sharpe Ratio: %s", e)
        raise

filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

        # Call the Sharpe Ratio calculation function
sharpe_json, sharpe_time, monthly_stats = cal_sharpe_ratio(merged_data, filter_column)
print("Execution Time:", sharpe_time, "seconds")
print("Sharpe Ratio:", sharpe_json)
print("\n")

# %% [markdown]
# **Sortino Ratio**
# *   Filters out rows where filter_column
# *   Find sum of market_value for the selected filter_column
# *   call cal_returns() give sthe daily returns
# *   Calculate risk by groupby filter column for the daily returns for a month
# *   Calculate the sortino ratio for each month over the specified period

# %%
def cal_sortino_ratio(df, filter_column, target_return=0.0):
    start_time = time.time()
    logging.info("Starting monthly Sortino Ratio calculation.")

    try:
        # Ensure 'report_date' is in datetime format
        df['report_date'] = pd.to_datetime(df['report_date'])

        # Call cal_returns function to get daily returns
        json_output, total_time, daily_returns = cal_returns(df, filter_column)

        # Drop NaN values in daily returns
        daily_returns.dropna(subset=['daily_returns'], inplace=True)

        # Set 'report_date' as the index
        daily_returns.set_index('report_date', inplace=True)

        # Filter for only negative returns for downside deviation calculation
        daily_returns['downside_returns'] = daily_returns['daily_returns'].apply(lambda x: min(0, x - target_return))

        # Resample by month for each group in filter_column and calculate average return and downside risk
        monthly_stats = daily_returns.groupby(filter_column).resample('M').agg(
            average_daily_return=('daily_returns', 'mean'),
            downside_risk=('downside_returns', lambda x: (x[x < 0].std()))
        ).reset_index()

        # Format 'report_date' to "YYYY-MM-DD"
        monthly_stats['report_date'] = monthly_stats['report_date'].dt.strftime('%Y-%m-%d')

        # Calculate the Sortino ratio for each group by month
        monthly_stats['sortino_ratio'] = (monthly_stats['average_daily_return'] - target_return) / monthly_stats['downside_risk']

        # Convert to JSON format for output
        json_output = monthly_stats[['report_date', filter_column, 'sortino_ratio']].to_json(orient='records', double_precision=2)
        logging.info("Converted monthly Sortino Ratio data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        # Display results
        #print("Sortino Ratio Results:")
        #print(monthly_stats)

        return json_output, total_time, monthly_stats

    except Exception as e:
        logging.error("Error calculating monthly Sortino Ratio: %s", e)
        raise

filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

sortino_json, sortino_time, monthly_stats = cal_sortino_ratio(merged_data, filter_column)
print("Execution Time:", sortino_time, "seconds")
print("Sortino Ratio:", sortino_json)
print("\n")

# %% [markdown]
# **Networth**

# %%
def cal_networth(start_date,end_date,df, filter_column):
    """Calculate net worth grouped by asset class and report date."""
    start_time = time.time()
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logging.info("Starting net worth calculation process.")

    try:
        # Load the data
        # df = get_data(filepath1)
        # if df is None:
        #     raise ValueError("Data loading failed due to missing columns.")

        # Ensure 'report_date' is in datetime format
        df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')

        # Generate month-end dates automatically for the desired range
        month_end_dates = pd.date_range(start_date,end_date , freq='M')

        # Filter for rows with dates matching the generated month-end dates
        filtered_df = df[df['report_date'].isin(month_end_dates)]

        # Group by asset_class and report_date, then sum market_value
        result_df = (
            filtered_df.groupby(['report_date',filter_column])['market_value']
            .sum()
            .reset_index()
        )

        # Rename columns for clarity
        result_df.columns = ['month_end_date', filter_column, 'Networth']

        logging.info("Grouped data by month-end date and filter column.")

        # Format 'month_end_date' to match the desired format (e.g., "YYYY-MM-DD")
        result_df['month_end_date'] = result_df['month_end_date'].dt.strftime('%Y-%m-%d')

        # Convert to JSON format for output
        json_output = result_df.to_json(orient='records', double_precision=2)
        logging.info("Converted net worth data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        return json_output, total_time, result_df

    except Exception as e:
        logging.error("Error processing net worth data: %s", e)
        raise

filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    # Load and merge data
    merged_data = merge_pos_security_sheet(filepath1, filepath2)

    # Convert 'report_date' to datetime format (ensure consistent format)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    # Define filter dictionary to include start_date, end_date, and asset_class_x
    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-06-30',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    # Convert start_date and end_date to datetime
    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])

    # Filter the data by report_date range
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
    logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

# Initialize filter_column to ensure it is defined
filter_column = None

# Get filter column input
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

# Map user choice to the corresponding filter column
if choice == 1:
    filter_column = 'asset_class_x'
elif choice == 2:
    filter_column = 'sub_asset_class'
elif choice == 3:
    filter_column = 'sub_industry'
elif choice == 4:
    filter_column = 'country_name'
else:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()  # Exiting using sys.exit() instead of 'return'

# Apply the selected filter if filter_column is valid
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

# Calculate and display returns
returns_json, returns_time, networth_df = cal_networth(start_date,end_date,merged_data, filter_column)
print("Execution Time:", returns_time, "seconds")
print("Networth:", returns_json)
print("\n")

# %% [markdown]
# **Single main function with filter**
# *   This will call all the core functions
# *   And we will take input from user to apply the filters only for Assset class Equity and Bonds over a period
# *  We will print the json for each core function along with the execution time

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import logging
import time
import warnings
import quantstats as qs  # For enhanced financial statistics

warnings.filterwarnings("ignore")

# Initialize logging once
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def main_stat():
    """Run core functions with sample data."""
    filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
    filepath2 = "/content/SECURITY_SHEET.csv"
    filepath3="/content/Mutual Funds dataset (1).csv"

    try:
        options = input("Mutual Funds or Others...")
        if options=="Mutual Funds":
           merged_data=get_data(filepath3)
                      # Convert 'report_date' to datetime format (ensure consistent format)
           merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

           # Define filter dictionary to include start_date, end_date, and asset_class_x
           filters = {
            "start_date": '2023-11-01',
            "end_date": '2024-12-31',
            "asset_class_x": ["Mutual Funds & Equivalent"],
            #"client_id":['dda49fb1-4172-4dc3-bbe0-97e9e6cbb873','a5a447c6-318f-480a-8bc0-cc037c0b31db']
            }

        else:
            # Load and merge data
            merged_data = merge_pos_security_sheet(filepath1, filepath2)

           # Convert 'report_date' to datetime format (ensure consistent format)
            merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

           # Define filter dictionary to include start_date, end_date, and asset_class_x
            filters = {
            "start_date": '2023-01-01',
            "end_date": '2024-06-30',
            "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"],
            #"client_id":['dda49fb1-4172-4dc3-bbe0-97e9e6cbb873','a5a447c6-318f-480a-8bc0-cc037c0b31db']
            }

        # Convert start_date and end_date to datetime
        start_date = pd.to_datetime(filters["start_date"])
        end_date = pd.to_datetime(filters["end_date"])

        # Filter the data by report_date range
        merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]
        logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

        # Initialize filter_column to ensure it is defined
        filter_column = None

        # Get filter column input
        choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

        # Map user choice to the corresponding filter column
        if choice == 1:
            filter_column = 'asset_class_x'
        elif choice == 2:
            filter_column = 'sub_asset_class'
        elif choice == 3:
            filter_column = 'sub_industry'
        elif choice == 4:
            filter_column = 'country_name'
        else:
            logging.error("Invalid choice entered. Exiting.")
            return  # Exit early if the choice is invalid

        # Apply the selected filter if filter_column is valid
        if filter_column in filters:
            if filter_column == "asset_class_x":
                merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
                logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")

       
        returns_json, returns_time, networth_df = cal_networth(start_date,end_date,merged_data, filter_column)
        print("Execution Time:", returns_time, "seconds")
        print("Networth:", returns_json)
        print("\n")
        
        # Calculate and display returns
        returns_json, returns_time, daily_returns = cal_returns(merged_data, filter_column)
        print("Execution Time:", returns_time, "seconds")
        print("Daily Returns:", returns_json)
        top_62_rows=daily_returns.head(62)
        print("\n")
        # top_62_rows.to_csv('top_62_data.csv', index=False)
        # print("Top 62 rows saved to 'top_62_data.csv'.")


        # Calculate and display returns
        returns_json, returns_time, results = cal_monthly_returns(merged_data, filter_column)
        print("Execution Time:", returns_time, "seconds")
        print("Monthly Returns:", returns_json)
        print("\n")

        # Calculate and display risk
        risk_json, risk_time, daily_returns = cal_risk(merged_data, filter_column)
        print("Execution Time:", risk_time, "seconds")
        print("Risk:", risk_json)
        print("\n")

        # Call the Sharpe Ratio calculation function
        sharpe_json, sharpe_time, monthly_stats = cal_sharpe_ratio(merged_data, filter_column)
        print("Execution Time:", sharpe_time, "seconds")
        print("Sharpe Ratio:", sharpe_json)
        print("\n")


        # Call the Sortino Ratio calculation function
        sortino_json, sortino_time, monthly_stats = cal_sortino_ratio(merged_data, filter_column)
        print("Execution Time:", sortino_time, "seconds")
        print("Sortino Ratio:", sortino_json)
        print("\n")
        

    except Exception as e:
        logging.error("An error occurred in main_stat function: %s", e)

# Function call
main_stat()
# Out:
# Mutual Funds or Others...Mutual Funds
# Enter your choice -
# 1. Asset Class
# 2. Sub Asset Class
# 3. Industry
# 4. Region
# 1
# Execution Time: 0.0414891242980957 seconds
# Networth: [{"month_end_date":"2023-11-30","asset_class_x":"Mutual Funds & Equivalent","Networth":126908916.7},{"month_end_date":"2023-12-31","asset_class_x":"Mutual Funds & Equivalent","Networth":65172546.96},{"month_end_date":"2024-01-31","asset_class_x":"Mutual Funds & Equivalent","Networth":128607780.49},{"month_end_date":"2024-02-29","asset_class_x":"Mutual Funds & Equivalent","Networth":129467278.51},{"month_end_date":"2024-03-31","asset_class_x":"Mutual Funds & Equivalent","Networth":129994375.63},{"month_end_date":"2024-04-30","asset_class_x":"Mutual Funds & Equivalent","Networth":130896057.23},{"month_end_date":"2024-05-31","asset_class_x":"Mutual Funds & Equivalent","Networth":131636070.96},{"month_end_date":"2024-06-30","asset_class_x":"Mutual Funds & Equivalent","Networth":100759691.37},{"month_end_date":"2024-07-31","asset_class_x":"Mutual Funds & Equivalent","Networth":134590603.62},{"month_end_date":"2024-08-31","asset_class_x":"Mutual Funds & Equivalent","Networth":100287494.46},{"month_end_date":"2024-09-30","asset_class_x":"Mutual Funds & Equivalent","Networth":136325725.97},{"month_end_date":"2024-10-31","asset_class_x":"Mutual Funds & Equivalent","Networth":136015442.25}]
#
#
# Execution Time: 0.27200865745544434 seconds
# Daily Returns: [{"report_date":"2023-11-23","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126297493.56,"daily_returns":null},{"report_date":"2023-11-24","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126589379.67,"daily_returns":0.0},{"report_date":"2023-11-25","asset_class_x":"Mutual Funds & Equivalent","total_market_value":62978439.69,"daily_returns":-0.5},{"report_date":"2023-11-26","asset_class_x":"Mutual Funds & Equivalent","total_market_value":62989091.22,"daily_returns":0.0},{"report_date":"2023-11-27","asset_class_x":"Mutual Funds & Equivalent","total_market_value":64969811.78,"daily_returns":0.03},{"report_date":"2023-11-28","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126716525.02,"daily_returns":0.95},{"report_date":"2023-11-29","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126846328.61,"daily_returns":0.0},{"report_date":"2023-11-30","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126908916.7,"daily_returns":0.0},{"report_date":"2023-12-01","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127005128.31,"daily_returns":0.0},{"report_date":"2023-12-02","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63007829.96,"daily_returns":-0.5},{"report_date":"2023-12-03","asset_class_x":"Mutual Funds & Equivalent","total_market_value":64990343.25,"daily_returns":0.03},{"report_date":"2023-12-04","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127271843.05,"daily_returns":0.96},{"report_date":"2023-12-05","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127352115.06,"daily_returns":0.0},{"report_date":"2023-12-06","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127393641.51,"daily_returns":0.0},{"report_date":"2023-12-07","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127434749.62,"daily_returns":0.0},{"report_date":"2023-12-08","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127457103.79,"daily_returns":0.0},{"report_date":"2023-12-09","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63064468.29,"daily_returns":-0.51},{"report_date":"2023-12-10","asset_class_x":"Mutual Funds & Equivalent","total_market_value":65048215.25,"daily_returns":0.03},{"report_date":"2023-12-11","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127543338.67,"daily_returns":0.96},{"report_date":"2023-12-12","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127496751.78,"daily_returns":-0.0},{"report_date":"2023-12-13","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127564170.8,"daily_returns":0.0},{"report_date":"2023-12-14","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127765136.47,"daily_returns":0.0},{"report_date":"2023-12-15","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127908123.29,"daily_returns":0.0},{"report_date":"2023-12-16","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63118319.51,"daily_returns":-0.51},{"report_date":"2023-12-17","asset_class_x":"Mutual Funds & Equivalent","total_market_value":65103195.52,"daily_returns":0.03},{"report_date":"2023-12-18","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127972134.57,"daily_returns":0.97},{"report_date":"2023-12-19","asset_class_x":"Mutual Funds & Equivalent","total_market_value":128005382.89,"daily_returns":0.0},{"report_date":"2023-12-20","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127748980.33,"daily_returns":-0.0},{"report_date":"2023-12-21","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127877291.89,"daily_returns":0.0},{"report_date":"2023-12-22","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127969320.24,"daily_returns":0.0},{"report_date":"2023-12-23","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63175751.59,"daily_returns":-0.51},{"report_date":"2023-12-24","asset_class ...
#
#
# Execution Time: 0.2249746322631836 seconds
# Monthly Returns: [{"asset_class_x":"Mutual Funds & Equivalent","month":"Nov","start_value":126297493.56,"end_value":126908916.7,"return_value":0.48},{"asset_class_x":"Mutual Funds & Equivalent","month":"Dec","start_value":127005128.31,"end_value":65172546.96,"return_value":-48.69},{"asset_class_x":"Mutual Funds & Equivalent","month":"Jan","start_value":128026342.19,"end_value":128607780.49,"return_value":0.45},{"asset_class_x":"Mutual Funds & Equivalent","month":"Feb","start_value":128730047.39,"end_value":129467278.51,"return_value":0.57},{"asset_class_x":"Mutual Funds & Equivalent","month":"Mar","start_value":129670086.57,"end_value":129994375.63,"return_value":0.25},{"asset_class_x":"Mutual Funds & Equivalent","month":"Apr","start_value":81759151.53,"end_value":130896057.23,"return_value":60.1},{"asset_class_x":"Mutual Funds & Equivalent","month":"May","start_value":65565774.67,"end_value":131636070.96,"return_value":100.77},{"asset_class_x":"Mutual Funds & Equivalent","month":"Jun","start_value":63744767.15,"end_value":100759691.37,"return_value":58.07},{"asset_class_x":"Mutual Funds & Equivalent","month":"Jul","start_value":133338149.34,"end_value":134590603.62,"return_value":0.94},{"asset_class_x":"Mutual Funds & Equivalent","month":"Aug","start_value":134586456.13,"end_value":100287494.46,"return_value":-25.48},{"asset_class_x":"Mutual Funds & Equivalent","month":"Sep","start_value":66349783.31,"end_value":136325725.97,"return_value":105.47},{"asset_class_x":"Mutual Funds & Equivalent","month":"Oct","start_value":136316302.47,"end_value":136015442.25,"return_value":-0.22},{"asset_class_x":"Mutual Funds & Equivalent","month":"Nov","start_value":64716506.06,"end_value":136931775.67,"return_value":111.59}]
#
#
# Execution Time: 0.18438935279846191 seconds
# Risk: [{"report_date":"2023-11-24","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126589379.67,"risk":0.45},{"report_date":"2023-11-25","asset_class_x":"Mutual Funds & Equivalent","total_market_value":62978439.69,"risk":0.45},{"report_date":"2023-11-26","asset_class_x":"Mutual Funds & Equivalent","total_market_value":62989091.22,"risk":0.45},{"report_date":"2023-11-27","asset_class_x":"Mutual Funds & Equivalent","total_market_value":64969811.78,"risk":0.45},{"report_date":"2023-11-28","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126716525.02,"risk":0.45},{"report_date":"2023-11-29","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126846328.61,"risk":0.45},{"report_date":"2023-11-30","asset_class_x":"Mutual Funds & Equivalent","total_market_value":126908916.7,"risk":0.45},{"report_date":"2023-12-01","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127005128.31,"risk":0.45},{"report_date":"2023-12-02","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63007829.96,"risk":0.45},{"report_date":"2023-12-03","asset_class_x":"Mutual Funds & Equivalent","total_market_value":64990343.25,"risk":0.45},{"report_date":"2023-12-04","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127271843.05,"risk":0.45},{"report_date":"2023-12-05","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127352115.06,"risk":0.45},{"report_date":"2023-12-06","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127393641.51,"risk":0.45},{"report_date":"2023-12-07","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127434749.62,"risk":0.45},{"report_date":"2023-12-08","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127457103.79,"risk":0.45},{"report_date":"2023-12-09","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63064468.29,"risk":0.45},{"report_date":"2023-12-10","asset_class_x":"Mutual Funds & Equivalent","total_market_value":65048215.25,"risk":0.45},{"report_date":"2023-12-11","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127543338.67,"risk":0.45},{"report_date":"2023-12-12","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127496751.78,"risk":0.45},{"report_date":"2023-12-13","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127564170.8,"risk":0.45},{"report_date":"2023-12-14","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127765136.47,"risk":0.45},{"report_date":"2023-12-15","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127908123.29,"risk":0.45},{"report_date":"2023-12-16","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63118319.51,"risk":0.45},{"report_date":"2023-12-17","asset_class_x":"Mutual Funds & Equivalent","total_market_value":65103195.52,"risk":0.45},{"report_date":"2023-12-18","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127972134.57,"risk":0.45},{"report_date":"2023-12-19","asset_class_x":"Mutual Funds & Equivalent","total_market_value":128005382.89,"risk":0.45},{"report_date":"2023-12-20","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127748980.33,"risk":0.45},{"report_date":"2023-12-21","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127877291.89,"risk":0.45},{"report_date":"2023-12-22","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127969320.24,"risk":0.45},{"report_date":"2023-12-23","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63175751.59,"risk":0.45},{"report_date":"2023-12-24","asset_class_x":"Mutual Funds & Equivalent","total_market_value":63186622.16,"risk":0.45},{"report_date":"2023-12-25","asset_class_x":"Mutual Funds & Equivalent","total_market_value":65172286.84,"risk":0.45},{"report_date":"2023-12-26","asset_class_x":"Mutual Funds & Equivalent","total_market_value":127982409.06,"risk":0.45},{"report_date":"2023-12-27","asset_class_x":"Mutual Funds & Equivalent","total_m ...
#
#
# Execution Time: 0.19653773307800293 seconds
# Sharpe Ratio: [{"report_date":"2023-11-30","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.09},{"report_date":"2023-12-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.04},{"report_date":"2024-01-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.15},{"report_date":"2024-02-29","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.09},{"report_date":"2024-03-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.12},{"report_date":"2024-04-30","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.16},{"report_date":"2024-05-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.13},{"report_date":"2024-06-30","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.1},{"report_date":"2024-07-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.14},{"report_date":"2024-08-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.1},{"report_date":"2024-09-30","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.15},{"report_date":"2024-10-31","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.12},{"report_date":"2024-11-30","asset_class_x":"Mutual Funds & Equivalent","sharpe_ratio":0.14}]
#
#
# Execution Time: 0.19415926933288574 seconds
# Sortino Ratio: [{"report_date":"2023-11-30","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":null},{"report_date":"2023-12-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.19},{"report_date":"2024-01-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.37},{"report_date":"2024-02-29","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.24},{"report_date":"2024-03-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.31},{"report_date":"2024-04-30","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.51},{"report_date":"2024-05-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.35},{"report_date":"2024-06-30","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.27},{"report_date":"2024-07-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.36},{"report_date":"2024-08-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.3},{"report_date":"2024-09-30","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.41},{"report_date":"2024-10-31","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.34},{"report_date":"2024-11-30","asset_class_x":"Mutual Funds & Equivalent","sortino_ratio":0.37}]

# %% [markdown]
# **CAGR**

# %%
import pandas as pd
import time
import logging
import sys

def cal_cagr(df, filter_column, start_date, end_date):
    start_time = time.time()
    logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
    logging.info("Starting CAGR calculation.")

    try:
        # Ensure 'report_date' is in datetime format
        df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')

        # Drop rows with invalid dates or missing values
        df.dropna(subset=['report_date', 'quantity', 'mtm_price', 'base_factor'], inplace=True)

        # Filter out unwanted asset classes
        df = df[(df['asset_class_x'] != 'Loan') & (df['asset_class_y'] != 'Loan')]

        # Calculate market value
        df['market_value'] = df['quantity'] * df['mtm_price'] * df.get('base_factor', 1)
        logging.info("Calculated market value.")

        # Filter data based on the provided date range
        df = df[(df['report_date'] >= start_date) & (df['report_date'] <= end_date)]
        logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")

        # Group by report_date and filter_column, then sum the market values
        grouped_data = (
            df.groupby(['report_date', filter_column])['market_value']
            .sum()
            .reset_index()
        )
        grouped_data.rename(columns={'market_value': 'total_market_value'}, inplace=True)

        # Sort data by report_date
        grouped_data.sort_values(by=['report_date'], inplace=True)

        # Initialize the results list to store CAGR for each group
        results_list = []

        # Iterate over unique asset classes (filter_column values)
        for asset_class in grouped_data[filter_column].unique():
            # Get the data for the specific asset class
            asset_class_data = grouped_data[grouped_data[filter_column] == asset_class]

            # Get the start and end values for CAGR calculation
            start_value = asset_class_data[asset_class_data['report_date'] == start_date]['total_market_value'].iloc[0]
            end_value = asset_class_data[asset_class_data['report_date'] == end_date]['total_market_value'].iloc[0]

            # Calculate number of years
            years = (end_date - start_date).days / 365.25

            # Calculate CAGR
            cagr = ((end_value / start_value) ** (1 / years)) - 1
            cagr_percentage = cagr * 100  # Convert to percentage

            # Store results for each asset class
            results = {
                filter_column: asset_class,
                'start_date': start_date.strftime('%b %d, %Y'),
                'end_date': end_date.strftime('%b %d, %Y'),
                'start_value': start_value,
                'end_value': end_value,
                'cagr_percentage': cagr_percentage
            }

            results_list.append(results)

        # Convert results to JSON format
        json_output = pd.DataFrame(results_list).to_json(orient='records', double_precision=2)
        logging.info("Converted CAGR data to JSON format.")

        end_time = time.time()
        total_time = end_time - start_time
        logging.info(f"Total execution time: {total_time:.2f} seconds")

        # Return JSON output and execution time
        return json_output, total_time, results_list

    except Exception as e:
        logging.error("Error processing CAGR calculation: %s", e)
        raise

# Sample usage
filepath1 = "/content/KP_CM_POSITION_HISTORY.csv"
filepath2 = "/content/SECURITY_SHEET.csv"
filepath3 = "/content/Mutual Funds dataset (1).csv"

options = input("Mutual Funds or Others...")

if options == "Mutual Funds":
    merged_data = get_data(filepath3)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    filters = {
        "start_date": '2023-11-01',
        "end_date": '2024-12-31',
        "asset_class_x": ["Mutual Funds & Equivalent"]
    }
else:
    merged_data = merge_pos_security_sheet(filepath1, filepath2)
    merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')

    filters = {
        "start_date": '2023-01-01',
        "end_date": '2024-01-31',
        "asset_class_x": ["Equity & Equivalents", "Bond & Equivalents"]
    }

    start_date = pd.to_datetime(filters["start_date"])
    end_date = pd.to_datetime(filters["end_date"])
    merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]

# Ensure filter_column exists in merged_data
filter_column = None
# Ensure 'report_date' is sorted and in datetime format
merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')
merged_data.sort_values(by='report_date', inplace=True)

# Dynamically determine the date range
start_date = merged_data['report_date'].iloc[0]
end_date = merged_data['report_date'].iloc[-1]

logging.info(f"Dynamic start_date set to: {start_date}")
logging.info(f"Dynamic end_date set to: {end_date}")

# Filter merged_data based on the dynamic date range
merged_data = merged_data[(merged_data['report_date'] >= start_date) & (merged_data['report_date'] <= end_date)]

# Ensure filter_column exists in merged_data
filter_column = None
choice = int(input("Enter your choice -\n1. Asset Class\n2. Sub Asset Class\n3. Industry\n4. Region\n"))

filter_mapping = {
    1: 'asset_class_x',
    2: 'sub_asset_class',
    3: 'sub_industry',
    4: 'country_name'
}

filter_column = filter_mapping.get(choice)

if not filter_column:
    logging.error("Invalid choice entered. Exiting.")
    sys.exit()

# Apply the selected filter column to merged_data
if filter_column in filters:
    if filter_column == "asset_class_x":
        merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
        logging.info(f"Data filtered based on {filter_column}: {filters[filter_column]}")
# Get unique values in 'asset_class_x' column
unique_asset_classes = merged_data['asset_class_x'].unique()

# Print the unique asset classes
print("Unique Asset Classes in 'asset_class_x':")
for asset_class in unique_asset_classes:
    print(asset_class)

# Perform CAGR calculation
cagr_json, cagr_time, results = cal_cagr(merged_data, filter_column, start_date, end_date)
print("Execution Time:", cagr_time, "seconds")
print("CAGR:", cagr_json)
print("\n")

# %% [markdown]
# **Alpha and Beta**

# %% [markdown]
# import pandas as pd
# import numpy as np
# import time
# import logging
# import sys
#
# # Beta Calculation Function
# def cal_beta(df, filter_column, start_date, end_date, benchmark_df):
#     start_time = time.time()
#     logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
#     logging.info("Starting Beta calculation.")
#
#     try:
#         # Ensure dates are in datetime format
#         df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')
#         benchmark_df['report_date'] = pd.to_datetime(benchmark_df['Date'], errors='coerce')
#
#         # Filter data for the given date range
#         df = df[(df['report_date'] >= start_date) & (df['report_date'] <= end_date)]
#         benchmark_df = benchmark_df[(benchmark_df['report_date'] >= start_date) & (benchmark_df['report_date'] <= end_date)]
#         logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")
#
#         # Calculate daily returns
#         df['daily_return'] = df.groupby([filter_column])['mtm_price'].pct_change()
#         benchmark_df['daily_return'] = benchmark_df['Close'].pct_change()
#
#         # Merge portfolio and benchmark data
#         merged_data = pd.merge(
#             df[['report_date', 'daily_return']].dropna(),
#             benchmark_df[['report_date', 'daily_return']].dropna(),
#             on='report_date',
#             suffixes=('_portfolio', '_benchmark')
#         )
#
#         # Calculate Beta
#         covariance = np.cov(merged_data['daily_return_portfolio'], merged_data['daily_return_benchmark'])[0][1]
#         benchmark_variance = np.var(merged_data['daily_return_benchmark'])
#         beta = covariance / benchmark_variance
#         logging.info(f"Beta calculated: {beta:.2f}")
#
#         total_time = time.time() - start_time
#         logging.info(f"Total execution time: {total_time:.2f} seconds")
#
#         return beta, total_time
#
#     except Exception as e:
#         logging.error(f"Error during Beta calculation: {e}")
#         raise
#
#
# def cal_alpha(df, filter_column, start_date, end_date, benchmark_df, risk_free_rate=0.03):
#     start_time = time.time()
#     logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
#     logging.info("Starting Alpha calculation.")
#
#     try:
#         # Ensure dates are in datetime format
#         df['report_date'] = pd.to_datetime(df['report_date'], errors='coerce')
#         benchmark_df['Date'] = pd.to_datetime(benchmark_df['Date'], errors='coerce')
#
#         # Filter data for the given date range
#         df = df[(df['report_date'] >= start_date) & (df['report_date'] <= end_date)]
#         benchmark_df = benchmark_df[(benchmark_df['Date'] >= start_date) & (benchmark_df['Date'] <= end_date)]
#         logging.info(f"Data filtered between {start_date.date()} and {end_date.date()}.")
#
#         # Calculate daily returns using mtm_price (or the correct column)
#         df['daily_return'] = df.groupby([filter_column])['mtm_price'].pct_change()
#
#         # Use 'Close' for the benchmark data to calculate daily returns
#         benchmark_df['daily_return'] = benchmark_df['Close'].pct_change()  # Corrected to 'Close'
#
#         # Merge portfolio and benchmark data
#         merged_data = pd.merge(
#             df[['report_date', 'daily_return']].dropna(),
#             benchmark_df[['Date', 'daily_return']].dropna(),
#             left_on='report_date', right_on='Date',
#             suffixes=('_portfolio', '_benchmark')
#         )
#
#         # Calculate Beta
#         covariance = np.cov(merged_data['daily_return_portfolio'], merged_data['daily_return_benchmark'])[0][1]
#         benchmark_variance = np.var(merged_data['daily_return_benchmark'])
#         beta = covariance / benchmark_variance
#
#         print(df)
#         print(benchmark_df)
#
#         # Calculate portfolio and benchmark annualized returns
#         portfolio_return = merged_data['daily_return_portfolio'].mean() * 252  # Assuming 252 trading days
#         benchmark_return = merged_data['daily_return_benchmark'].mean() * 252
#
#         # Calculate Alpha
#         alpha = portfolio_return - (risk_free_rate + beta * (benchmark_return - risk_free_rate))
#         logging.info(f"Alpha calculated: {alpha:.2f}")
#
#         total_time = time.time() - start_time
#         logging.info(f"Total execution time: {total_time:.2f} seconds")
#
#         return alpha, total_time
#
#     except Exception as e:
#         logging.error(f"Error during Alpha calculation: {e}")
#         raise
#
# # Sample usage
# filepath3 = "/content/New Mutual Funds Dataset.csv"
# filepath4 = "/content/Benchmark Data.csv"
#
# merged_data = pd.read_csv(filepath3)
# merged_data['report_date'] = pd.to_datetime(merged_data['report_date'], errors='coerce')
#
# benchmark_data = pd.read_csv(filepath4)
# benchmark_data['Date'] = pd.to_datetime(benchmark_data['Date'], errors='coerce')
#
# # Filtering configuration
# filters = {
#     "start_date": pd.Timestamp('2023-11-01'),
#     "end_date": pd.Timestamp('2024-09-30'),
#     "asset_class_x": ["Mutual Funds & Equivalent"]
# }
#
# # Validate filter_column and apply filter
# filter_column = 'asset_class_x'
# merged_data = merged_data[merged_data[filter_column].isin(filters[filter_column])]
# logging.info(f"Filtered data for {filter_column}: {filters[filter_column]}")
#
# # Calculate Beta
# beta, beta_time = cal_beta(merged_data, filter_column, filters['start_date'], filters['end_date'], benchmark_data)
# print(f"Beta: {beta}, Execution Time: {beta_time} seconds")
#
# # Calculate Alpha
# alpha, alpha_time = cal_alpha(merged_data, filter_column, filters['start_date'], filters['end_date'], benchmark_data, risk_free_rate=0.03)
# print(f"Alpha: {alpha}, Execution Time: {alpha_time} seconds")
